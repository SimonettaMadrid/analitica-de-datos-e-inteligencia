# %% [markdown]
# # Bareclona!

# %% [markdown]
# ### instalación de librerias

# %%
#INSTALAR LIBRERIAS
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install openpyxl

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### dataframe y caracteristicas

# %%
#Convertimos el dataset en dataframe
df= pd.read_csv("listingsbarcelona.csv")
df
# Out:
#                         id                                       listing_url  \
# 0                    18674                https://www.airbnb.com/rooms/18674
# 1                    23197                https://www.airbnb.com/rooms/23197
# 2                    32711                https://www.airbnb.com/rooms/32711
# 3                    34241                https://www.airbnb.com/rooms/34241
# 4                   347824               https://www.airbnb.com/rooms/347824
# ...                    ...                                               ...
# 18922  1440378586135901437  https://www.airbnb.com/rooms/1440378586135901437
# 18923  1440379191108051829  https://www.airbnb.com/rooms/1440379191108051829
# 18924  1440379869744969989  https://www.airbnb.com/rooms/1440379869744969989
# 18925  1440380503685655376  https://www.airbnb.com/rooms/1440380503685655376
# 18926  1440381140081945750  https://www.airbnb.com/rooms/1440381140081945750
#
# ...

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18927 entries, 0 to 18926
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            18927 non-null  int64
#  1   listing_url                                   18927 non-null  object
#  2   scrape_id                                     18927 non-null  int64
#  3   last_scraped                                  18927 non-null  object
#  4   source                                        18927 non-null  object
#  5   name                                          18927 non-null  object
#  6   description                                   18189 non-null  object
#  7   neighborhood_overview                         9154 non-null   object
#  8   picture_url                                   18927 non-null  object
# ...

# %%
# Acceder a una Fila única (Array 1D)
fila0 = df.iloc[0]
fila0
# Out:
# id                                                                           18674
# listing_url                                     https://www.airbnb.com/rooms/18674
# scrape_id                                                           20250612050654
# last_scraped                                                            2025-06-21
# source                                                                 city scrape
#                                                                ...
# calculated_host_listings_count                                                  28
# calculated_host_listings_count_entire_homes                                     28
# calculated_host_listings_count_private_rooms                                     0
# calculated_host_listings_count_shared_rooms                                      0
# reviews_per_month                                                             0.33
# Name: 0, Length: 79, dtype: object

# %% [markdown]
# Aqui podemos observar las variables que contiene nuestro dataframe y con las cuales vamos a trabajar.

# %% [markdown]
# ahora vamos a filtrar las variables para que solo sean 50.

# %%
#Filas combinadas y Todas las columnas
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %% [markdown]
# ### 50 variables elegidas

# %%
_dfde50 = df.iloc[:, [
    3, 9, 12, 15, 16, 17, 18, 22,
    26, 27, 28, 30, 31,
    32, 33, 34, 35, 37,
    38, 39, 40, 41, 42,
    43, 46, 51, 52, 53, 54, 55, 56, 57, 58, 61, 62,
    63, 64, 65, 66, 67, 68, 69, 70, 71,
    72, 73, 74, 75,
    76, 77]]

# %%
_dfde50
# Out:
#       last_scraped  host_id  host_since host_response_time host_response_rate  \
# 0       2025-06-21    71615  2010-01-19     within an hour                96%
# 1       2025-06-23    90417  2010-03-09     within an hour               100%
# 2       2025-06-22   135703  2010-05-31     within an hour               100%
# 3       2025-06-22    73163  2010-01-24     within an hour                80%
# 4       2025-06-22  1447144  2011-11-27     within an hour                87%
# ...            ...      ...         ...                ...                ...
# 18922   2025-06-26  4459553  2012-12-21     within an hour               100%
# 18923   2025-06-21  4459553  2012-12-21     within an hour               100%
# 18924   2025-06-21  4459553  2012-12-21     within an hour               100%
# 18925   2025-06-23  4459553  2012-12-21     within an hour               100%
# 18926   2025-06-22  4459553  2012-12-21     within an hour               100%
#
# ...

# %% [markdown]
# ### se corrobora

# %%
num_columnas = _dfde50.shape[1]
num_columnas
# Out:
# 50

# %% [markdown]
# ### convertir a Csv

# %%
#Convertir array a CSV
_dfde50.to_csv("barcelona50.csv")
