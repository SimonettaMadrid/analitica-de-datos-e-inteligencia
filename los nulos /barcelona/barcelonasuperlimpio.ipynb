# %% [markdown]
# ### limpieza de datos Barcelonaaa :0

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
###cargamos los datos
data = pd.read_csv('listingsbarcelona.csv')

# %%
pd.set_option("display.max_rows", None)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18927 entries, 0 to 18926
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            18927 non-null  int64
#  1   listing_url                                   18927 non-null  object
#  2   scrape_id                                     18927 non-null  int64
#  3   last_scraped                                  18927 non-null  object
#  4   source                                        18927 non-null  object
#  5   name                                          18927 non-null  object
#  6   description                                   18189 non-null  object
#  7   neighborhood_overview                         9154 non-null   object
#  8   picture_url                                   18927 non-null  object
# ...

# %%
pd.set_option("display.max_rows", None)
data.isnull().sum().sort_values(ascending=False)
# Out:
# calendar_updated                                18927
# host_neighbourhood                               9776
# neighbourhood                                    9773
# neighborhood_overview                            9773
# host_about                                       6775
# license                                          6329
# review_scores_checkin                            5002
# review_scores_accuracy                           5001
# review_scores_value                              5001
# review_scores_location                           5001
# review_scores_cleanliness                        5000
# review_scores_communication                      4999
# first_review                                     4998
# last_review                                      4998
# review_scores_rating                             4998
# reviews_per_month                                4998
# host_location                                    4376
# ...

# %%
data1 = data.copy()

# %% [markdown]
# #### para neighbourhood Barcelona, Catalonia, Spain
# #### para host_neighbourhood se elaboro el barrio mas comun y se inserto como dato random para mejorar la credibilidad y eliminar los nulos

# %%
data1["neighbourhood"] =data1["neighbourhood"].fillna("Barcelona, Catalonia, Spain")
data1["neighbourhood"].isnull().sum()
# Out:
# 0

# %%
barrio_mas_comun = data1['host_neighbourhood'].mode()[0]
data1['host_neighbourhood'] = data1['host_neighbourhood'].fillna(barrio_mas_comun)
data1['host_neighbourhood'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### para estas dos variables se utiliza la palabra no dato ya qye si los eiminamos nos podriamos llevar parte importante de ellos neighborhood_overview ,host_about, description

# %%
data1["description"] =data1["description"].fillna("No Data")
data1["description"].isnull().sum()
# Out:
# 0

# %%
data1["host_about"] =data1["host_about"].fillna("No Data")
data1["host_about"].isnull().sum()
# Out:
# 0

# %%
                        
data1["neighborhood_overview"] =data1["neighborhood_overview"].fillna("No Data")
data1["neighborhood_overview"].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### license con exempt que en el diccionario significa no registro

# %%
data1["license"] = data1["license"].fillna("exempt")
data1["license"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### las numericas
# Para las numericas utilice el mejor metodo etre ellas para imputar datos
# ### review_scores_value, review_scores_accuracy,review_scores_checkin
# ### review_scores_communication, review_scores_cleanliness
# ### review_scores_location review_scores_rating                      reviews_per_month, review_scores_location

# %%
data1['reviews_per_month'] = data1['reviews_per_month'].fillna(data1['reviews_per_month'].mean())
data1['reviews_per_month'].isnull().sum()
# Out:
# 0

# %%
data1['review_scores_location'] = data1['review_scores_location'].fillna(data1['review_scores_location'].mean())
data1['review_scores_location'].isnull().sum()
# Out:
# 0

# %%
data1['review_scores_rating'] = data1['review_scores_rating'].fillna(data1['review_scores_rating'].mean())
data1['review_scores_rating'].isnull().sum()
# Out:
# 0

# %%
data1['review_scores_communication'] = data1['review_scores_communication'].fillna(data1['review_scores_communication'].mean())
data1['review_scores_communication'].isnull().sum()
# Out:
# 0

# %%
data1['review_scores_cleanliness'] = data1['review_scores_cleanliness'].fillna(data1['review_scores_cleanliness'].mean())
data1['review_scores_cleanliness'].isnull().sum()
# Out:
# 0

# %%
data1['review_scores_value'] = data1['review_scores_value'].fillna(data1['review_scores_value'].mean())
data1['review_scores_value'].isnull().sum()
# Out:
# 0

# %%
data1['review_scores_accuracy'] = data1['review_scores_accuracy'].fillna(data1['review_scores_accuracy'].mean())
data1['review_scores_accuracy'].isnull().sum()
# Out:
# 0

# %%
data1['review_scores_checkin'] = data1['review_scores_checkin'].fillna(data1['review_scores_checkin'].mean())
data1['review_scores_checkin'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### eliminar los porcentajes para eliminar nulos y comenzar a trabajar con ellos
# host_acceptance_rate
# host_response_time
# host_response_rate

# %%
data1["host_acceptance_rate"] = data1["host_acceptance_rate"].str.replace("%", "", regex=False).astype(float)

# %%
data1['host_acceptance_rate'] = data1['host_acceptance_rate'].fillna(data1['host_acceptance_rate'].mean())
data1['host_acceptance_rate'].isnull().sum()
# Out:
# 0

# %%
data1["host_response_time"] = data1["host_response_time"].fillna("unknown")
data1["host_response_time"].isnull().sum()
# Out:
# 0

# %%
data1['host_response_rate'] = data1['host_response_rate'].str.replace("%", "", regex=False).astype(float)

# %%
data1['host_response_rate'] = data1['host_response_rate'].fillna(data1['host_response_rate'].mean())
data1['host_response_rate'].isnull().sum()
# Out:
# 0

# %%
data1.isnull().sum().sort_values(ascending=False)
# Out:
# calendar_updated                                18927
# first_review                                     4998
# last_review                                      4998
# host_location                                    4376
# beds                                             4053
# estimated_revenue_l365d                          4014
# price                                            4014
# bathrooms                                        3985
# bedrooms                                         2057
# has_availability                                 1089
# host_is_superhost                                 567
# bathrooms_text                                      8
# minimum_minimum_nights                              4
# maximum_minimum_nights                              4
# minimum_maximum_nights                              4
# maximum_maximum_nights                              4
# host_identity_verified                              3
# ...

# %%
## eliminamos calendar_update 
data2 = data1.copy()
data2 = data2.drop(columns=['calendar_updated'])

# %%
data2.isnull().sum().sort_values(ascending=False)
# Out:
# last_review                                     4998
# first_review                                    4998
# host_location                                   4376
# beds                                            4053
# estimated_revenue_l365d                         4014
# price                                           4014
# bathrooms                                       3985
# bedrooms                                        2057
# has_availability                                1089
# host_is_superhost                                567
# bathrooms_text                                     8
# minimum_minimum_nights                             4
# maximum_minimum_nights                             4
# minimum_maximum_nights                             4
# maximum_maximum_nights                             4
# host_identity_verified                             3
# host_picture_url                                   3
# host_total_listings_count                          3
# ...

# %% [markdown]
# ### metodos bfill y ffill last_review                                  first_review has_availability

# %%
data2['has_availability'] = data2['has_availability'].fillna(method='bfill')
# Out:
# /var/folders/6c/rr21_80s11n3cvrghbnb5mz00000gn/T/ipykernel_35972/922782330.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data2['has_availability'] = data2['has_availability'].fillna(method='bfill')

# %%
data2['last_review'] = data2['last_review'].fillna(method='ffill')
# Out:
# /var/folders/6c/rr21_80s11n3cvrghbnb5mz00000gn/T/ipykernel_35972/2138805636.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data2['last_review'] = data2['last_review'].fillna(method='ffill')

# %%
data2['first_review']=data2['first_review'].fillna(method='ffill')
# Out:
# /var/folders/6c/rr21_80s11n3cvrghbnb5mz00000gn/T/ipykernel_35972/1213083311.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data2['first_review']=data2['first_review'].fillna(method='ffill')

# %%
###host_is_superhost
data2['host_is_superhost']=data2['host_is_superhost'].fillna(method='ffill')
# Out:
# /var/folders/6c/rr21_80s11n3cvrghbnb5mz00000gn/T/ipykernel_35972/584976748.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data2['host_is_superhost']=data2['host_is_superhost'].fillna(method='ffill')

# %%
data2['host_location'] = data2['host_location'].fillna(method='ffill')
# Out:
# /var/folders/6c/rr21_80s11n3cvrghbnb5mz00000gn/T/ipykernel_35972/3557747894.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data2['host_location'] = data2['host_location'].fillna(method='ffill')

# %%
data2['estimated_revenue_l365d'] = data2['estimated_revenue_l365d'].fillna(method='ffill')
# Out:
# /var/folders/6c/rr21_80s11n3cvrghbnb5mz00000gn/T/ipykernel_35972/2005603103.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data2['estimated_revenue_l365d'] = data2['estimated_revenue_l365d'].fillna(method='ffill')

# %%
data2.isnull().sum().sort_values(ascending=False)
# Out:
# beds                                            4053
# price                                           4014
# bathrooms                                       3985
# bedrooms                                        2057
# bathrooms_text                                     8
# maximum_maximum_nights                             4
# minimum_maximum_nights                             4
# maximum_minimum_nights                             4
# minimum_minimum_nights                             4
# host_identity_verified                             3
# host_has_profile_pic                               3
# host_total_listings_count                          3
# host_listings_count                                3
# host_picture_url                                   3
# host_thumbnail_url                                 3
# host_verifications                                 3
# host_since                                         3
# host_name                                          3
# ...

# %% [markdown]
# ### beds badroom bedroom
# por medio de moda media y mediana

# %%
data3=data2.copy()

# %%
data3['beds'] = data3['beds'].fillna(data3['beds'].mean())
data3['beds'].isnull().sum()
# Out:
# 0

# %%
data3['bedrooms'] = data3['bedrooms'].fillna(data3['bedrooms'].mean())
data3['bedrooms'].isnull().sum()
# Out:
# 0

# %%
data3['bathrooms'] = data3['bathrooms'].fillna(data3['bathrooms'].mean())
data3['bathrooms'].isnull().sum()
# Out:
# 0

# %%
data3['description'] = data3['description'].fillna("No Data")
data3['description'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### para price ffill

# %%
data3['price'] = data3['price'].fillna(method='ffill')
# Out:
# /var/folders/6c/rr21_80s11n3cvrghbnb5mz00000gn/T/ipykernel_35972/3759421995.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data3['price'] = data3['price'].fillna(method='ffill')

# %%
data3.isnull().sum().sort_values(ascending=False)
# Out:
# bathrooms_text                                  8
# maximum_minimum_nights                          4
# minimum_minimum_nights                          4
# maximum_maximum_nights                          4
# minimum_maximum_nights                          4
# host_since                                      3
# host_identity_verified                          3
# host_has_profile_pic                            3
# host_verifications                              3
# host_total_listings_count                       3
# host_picture_url                                3
# host_thumbnail_url                              3
# host_listings_count                             3
# host_name                                       3
# review_scores_checkin                           0
# number_of_reviews_l30d                          0
# calculated_host_listings_count_shared_rooms     0
# calculated_host_listings_count_private_rooms    0
# minimum_nights_avg_ntm                          0
# ...

# %%
### eliminar los nulos restantes por drop ya que es un porcentaje bajo
data5= data3.copy()
data5= data5.dropna()

# %%
data5.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### hacemos la comparación

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18927 entries, 0 to 18926
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            18927 non-null  int64
#  1   listing_url                                   18927 non-null  object
#  2   scrape_id                                     18927 non-null  int64
#  3   last_scraped                                  18927 non-null  object
#  4   source                                        18927 non-null  object
#  5   name                                          18927 non-null  object
#  6   description                                   18189 non-null  object
#  7   neighborhood_overview                         9154 non-null   object
#  8   picture_url                                   18927 non-null  object
# ...

# %%
data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18912 entries, 0 to 18926
# Data columns (total 78 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            18912 non-null  int64
#  1   listing_url                                   18912 non-null  object
#  2   scrape_id                                     18912 non-null  int64
#  3   last_scraped                                  18912 non-null  object
#  4   source                                        18912 non-null  object
#  5   name                                          18912 non-null  object
#  6   description                                   18912 non-null  object
#  7   neighborhood_overview                         18912 non-null  object
#  8   picture_url                                   18912 non-null  object
# ...

# %%
#Convertir DataFrame a CSV
data5.to_csv("barcelona_super_limpio.csv", index=False)
