# %% [markdown]
# # Index Barcelona

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Convertimos el dataset en dataframe
dfbarcelona= pd.read_csv("listingsbarcelona.csv")
dfbarcelona
# Out:
#                         id                                       listing_url  \
# 0                    18674                https://www.airbnb.com/rooms/18674
# 1                    23197                https://www.airbnb.com/rooms/23197
# 2                    32711                https://www.airbnb.com/rooms/32711
# 3                    34241                https://www.airbnb.com/rooms/34241
# 4                   347824               https://www.airbnb.com/rooms/347824
# ...                    ...                                               ...
# 18922  1440378586135901437  https://www.airbnb.com/rooms/1440378586135901437
# 18923  1440379191108051829  https://www.airbnb.com/rooms/1440379191108051829
# 18924  1440379869744969989  https://www.airbnb.com/rooms/1440379869744969989
# 18925  1440380503685655376  https://www.airbnb.com/rooms/1440380503685655376
# 18926  1440381140081945750  https://www.airbnb.com/rooms/1440381140081945750
#
# ...

# %%
dfbarcelona.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %% [markdown]
# ### array 2d columnas host_name, host since, neighbourhood, property_type, room_type

# %%
dfbarcelona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18927 entries, 0 to 18926
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            18927 non-null  int64
#  1   listing_url                                   18927 non-null  object
#  2   scrape_id                                     18927 non-null  int64
#  3   last_scraped                                  18927 non-null  object
#  4   source                                        18927 non-null  object
#  5   name                                          18927 non-null  object
#  6   description                                   18189 non-null  object
#  7   neighborhood_overview                         9154 non-null   object
#  8   picture_url                                   18927 non-null  object
# ...

# %%
# Acceder a más de una Columna (Array 2D)
columnas1 = dfbarcelona[['host_name', 'host_since', 'neighbourhood', 'property_type', 'room_type']] 
columnas1
# Out:
#                     host_name  host_since  \
# 0               Mireia  Maria  2010-01-19
# 1              Etain (Marnie)  2010-03-09
# 2                        Nick  2010-05-31
# 3                      Andres  2010-01-24
# 4         Acomodis Apartments  2011-11-27
# ...                       ...         ...
# 18922  AB Apartment Barcelona  2012-12-21
# 18923  AB Apartment Barcelona  2012-12-21
# 18924  AB Apartment Barcelona  2012-12-21
# 18925  AB Apartment Barcelona  2012-12-21
# 18926  AB Apartment Barcelona  2012-12-21
#
#                                neighbourhood       property_type  \
# 0                       Barcelona, CT, Spain  Entire rental unit
# 1      Sant Adria de Besos, Barcelona, Spain  Entire rental unit
# 2                Barcelona, Catalonia, Spain  Entire rental unit
# 3                                        NaN        Entire condo
# 4                                        NaN  Entire rental unit
# ...

# %% [markdown]
# array 1,50,100-200,499,500,606,1500,80000,15000

# %%
#Filas combinadas 
df3= dfbarcelona.iloc[ [1,50,500,605,1500,8000,15000] + list(range(100, 200)), : ]  
df3
# Out:
#            id                           listing_url       scrape_id  \
# 1       23197    https://www.airbnb.com/rooms/23197  20250612050654
# 50      80004    https://www.airbnb.com/rooms/80004  20250612050654
# 500   1241225  https://www.airbnb.com/rooms/1241225  20250612050654
# 605   1642382  https://www.airbnb.com/rooms/1642382  20250612050654
# 1500  5475163  https://www.airbnb.com/rooms/5475163  20250612050654
# ...       ...                                   ...             ...
# 195    684643   https://www.airbnb.com/rooms/684643  20250612050654
# 196    688295   https://www.airbnb.com/rooms/688295  20250612050654
# 197    688527   https://www.airbnb.com/rooms/688527  20250612050654
# 198    688946   https://www.airbnb.com/rooms/688946  20250612050654
# 199    689713   https://www.airbnb.com/rooms/689713  20250612050654
#
#      last_scraped           source  \
# 1      2025-06-23      city scrape
# 50     2025-06-24      city scrape
# 500    2025-06-22      city scrape
# ...

# %%
#Filas combinadas 
df4= dfbarcelona.iloc[ [125,252,700,1000] + list(range(300, 550))+list(range(1250,18926)) , :]
df4
df5=df4[['host_id','host_acceptance_rate','bathrooms', 'amenities', 'review_scores_value','host_location']]  
df5
# Out:
#         host_id host_acceptance_rate  bathrooms  \
# 125     2846323                 100%        3.0
# 252     2041901                 100%        2.0
# 700     8232918                  39%        1.0
# 1000   17082106                  53%        1.0
# 300     1432835                  90%        1.0
# ...         ...                  ...        ...
# 18921  49813494                  98%        1.0
# 18922   4459553                  79%        2.0
# 18923   4459553                  79%        2.0
# 18924   4459553                  79%        2.0
# 18925   4459553                  79%        1.0
#
#                                                amenities  review_scores_value  \
# 125    ["Bed linens", "Oven", "AC - split type ductle...                 4.80
# 252    ["Bed linens", "Oven", "Central heating", "Hot...                 4.67
# 700    ["Clothing storage: closet", "Shower gel", "Fr...                 4.55
# ...

# %% [markdown]
# 50 columnas

# %%
dfbarcelona50= dfbarcelona[["latitude",
    "longitude",
    "neighbourhood",
    "neighbourhood_cleansed",
    "property_type",
    "room_type","accommodates",
    "bathrooms",
    "bedrooms",
    "beds",
    "amenities","price",
    "minimum_nights",
    "maximum_nights",
    "minimum_minimum_nights",
    "maximum_maximum_nights",
    "availability_30",
    "availability_60",
    "availability_90",
    "availability_365","number_of_reviews",
    "number_of_reviews_ltm",
    "number_of_reviews_l30d",
    "estimated_occupancy_l365d",
    "estimated_revenue_l365d","review_scores_rating",
    "review_scores_accuracy",
    "review_scores_cleanliness",
    "review_scores_checkin",
    "review_scores_communication",
    "review_scores_location",
    "review_scores_value","host_id",
    "host_since",
    "host_response_time",
    "host_response_rate",
    "host_acceptance_rate",
    "host_is_superhost",
    "host_listings_count",
    "host_identity_verified", "last_scraped",
    "first_review",
    "last_review",
    "calendar_last_scraped",
    "instant_bookable",
    "license",
    "calculated_host_listings_count",
    "calculated_host_listings_count_entire_homes",
    "calculated_host_listings_count_private_rooms",
    "calculated_host_listings_count_shared_rooms"]]
dfbarcelona50
# Out:
#         latitude  longitude                          neighbourhood  \
# 0      41.405560   2.172620                   Barcelona, CT, Spain
# 1      41.412432   2.219750  Sant Adria de Besos, Barcelona, Spain
# 2      41.405660   2.170150            Barcelona, Catalonia, Spain
# 3      41.380620   2.175170                                    NaN
# 4      41.376400   2.191020                                    NaN
# ...          ...        ...                                    ...
# 18922  41.399220   2.178950            Barcelona, Catalonia, Spain
# 18923  41.399790   2.180350            Barcelona, Catalonia, Spain
# 18924  41.399390   2.180520            Barcelona, Catalonia, Spain
# 18925  41.400813   2.180756            Barcelona, Catalonia, Spain
# 18926  41.410760   2.179390            Barcelona, Catalonia, Spain
#
#                    neighbourhood_cleansed       property_type  \
# 0                      la Sagrada Família  Entire rental unit
# ...

# %%
dfbarcelona50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18927 entries, 0 to 18926
# Data columns (total 50 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   latitude                                      18927 non-null  float64
#  1   longitude                                     18927 non-null  float64
#  2   neighbourhood                                 9154 non-null   object
#  3   neighbourhood_cleansed                        18927 non-null  object
#  4   property_type                                 18927 non-null  object
#  5   room_type                                     18927 non-null  object
#  6   accommodates                                  18927 non-null  int64
#  7   bathrooms                                     14942 non-null  float64
#  8   bedrooms                                      16870 non-null  float64
# ...

# %% [markdown]
# creación de csv

# %%
#punto a 
columnas1.to_csv("Abarcelona.csv")
#punto b
df3.to_csv("Bbarcelona.csv")
#punto c 
df5.to_csv("Cbarcelona.csv")
#los 50 
dfbarcelona50.to_csv("50debarcelona.csv")
